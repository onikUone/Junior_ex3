# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# ex1_データセット初期化
dataX1_class1_ex1 = np.asarray([], dtype=np.float64)
dataX2_class1_ex1 = np.asarray([], dtype=np.float64)
dataX1_class2_ex1 = np.asarray([], dtype=np.float64)
dataX2_class2_ex1 = np.asarray([], dtype=np.float64)
dataX1_class3_ex1 = np.asarray([], dtype=np.float64)
dataX2_class3_ex1 = np.asarray([], dtype=np.float64)

# ---------------ファイル読み込み開始---------------
    #Mac(ノートPC)環境用パス
dataset_path_1 = '/Users/Uone/IDrive/OPU/研究フォルダ/Junior_ex3/eclipse_workspace/Junior_ex3/src/kadai3_pattern1.txt'
    #研究室 Windows環境用パス
# dataset_path_1 = 'C:\\Users\\Yuichi Omozaki\\IDrive\\Junior_ex3\\eclipse_workspace\\Junior_ex3\\src\\kadai3_pattern1.txt'

    #Mac(ノートPC)環境用パス
dataset_path_2 = '/Users/Uone/IDrive/OPU/研究フォルダ/Junior_ex3/eclipse_workspace/Junior_ex3/src/kadai3_pattern2.txt'
    #研究室 Windows環境用パス
# dataset_path_2 = 'C:\\Users\\Yuichi Omozaki\\IDrive\\Junior_ex3\\eclipse_workspace\\Junior_ex3\\src\\kadai3_pattern2.txt'

flg=0
for line in open(dataset_path_1, 'r'):
    if flg==0:
            flg = 1
            continue
    if line[:-1].split(', ')[2] == "0":
        dataX1_class1_ex1 = np.append( dataX1_class1_ex1, line[:-1].split(', ')[0] )
        dataX2_class1_ex1 = np.append( dataX2_class1_ex1, line[:-1].split(', ')[1] )
    elif line[:-1].split(', ')[2] == "1":
        dataX1_class2_ex1 = np.append( dataX1_class2_ex1, line[:-1].split(', ')[0] )
        dataX2_class2_ex1 = np.append( dataX2_class2_ex1, line[:-1].split(', ')[1] )
    elif line[:-1].split(', ')[2] == "2":
        dataX1_class3_ex1 = np.append( dataX1_class3_ex1, line[:-1].split(', ')[0] )
        dataX2_class3_ex1 = np.append( dataX2_class3_ex1, line[:-1].split(', ')[1] )

dataX1_class1_ex1 = dataX1_class1_ex1.astype(np.float64) #型変換
dataX2_class1_ex1 = dataX2_class1_ex1.astype(np.float64) #
dataX1_class2_ex1 = dataX1_class2_ex1.astype(np.float64) #
dataX2_class2_ex1 = dataX2_class2_ex1.astype(np.float64) #
dataX1_class3_ex1 = dataX1_class3_ex1.astype(np.float64) #
dataX2_class3_ex1 = dataX2_class3_ex1.astype(np.float64) #
# ---------------ex1_ファイル読み込み完了---------------

# ex2_データセット初期化
dataX1_class1_ex2 = np.asarray([], dtype=np.float64)
dataX2_class1_ex2 = np.asarray([], dtype=np.float64)
dataX1_class2_ex2 = np.asarray([], dtype=np.float64)
dataX2_class2_ex2 = np.asarray([], dtype=np.float64)
dataX1_class3_ex2 = np.asarray([], dtype=np.float64)
dataX2_class3_ex2 = np.asarray([], dtype=np.float64)

flg=0
for line in open(dataset_path_2, 'r'):
    if flg==0:
            flg = 1
            continue
    if line[:-1].split(', ')[2] == "0":
        dataX1_class1_ex2 = np.append( dataX1_class1_ex2, line[:-1].split(', ')[0] )
        dataX2_class1_ex2 = np.append( dataX2_class1_ex2, line[:-1].split(', ')[1] )
    elif line[:-1].split(', ')[2] == "1":
        dataX1_class2_ex2 = np.append( dataX1_class2_ex2, line[:-1].split(', ')[0] )
        dataX2_class2_ex2 = np.append( dataX2_class2_ex2, line[:-1].split(', ')[1] )
    elif line[:-1].split(', ')[2] == "2":
        dataX1_class3_ex2 = np.append( dataX1_class3_ex2, line[:-1].split(', ')[0] )
        dataX2_class3_ex2 = np.append( dataX2_class3_ex2, line[:-1].split(', ')[1] )

dataX1_class1_ex2 = dataX1_class1_ex2.astype(np.float64) #型変換
dataX2_class1_ex2 = dataX2_class1_ex2.astype(np.float64) #
dataX1_class2_ex2 = dataX1_class2_ex2.astype(np.float64) #
dataX2_class2_ex2 = dataX2_class2_ex2.astype(np.float64) #
dataX1_class3_ex2 = dataX1_class3_ex2.astype(np.float64) #
dataX2_class3_ex2 = dataX2_class3_ex2.astype(np.float64) #
# ---------------ex2_ファイル読み込み完了---------------


# データセット描画
fig_dataset = plt.figure(figsize=(15,10))
# fig_dataset.subplots_adjust(wspace=0.4, hspace=0.4)
axes_dataset_ex1 = fig_dataset.add_subplot(231)
axes_dataset_ex1.set_title("kadai3_pattern1.txt")
axes_dataset_ex1.scatter(dataX1_class1_ex1, dataX2_class1_ex1, marker='o', c="red", label="Class 1")
axes_dataset_ex1.scatter(dataX1_class2_ex1, dataX2_class2_ex1, marker='o', c="blue", label="Class 2")
axes_dataset_ex1.scatter(dataX1_class3_ex1, dataX2_class3_ex1, marker='o', c="green", label="Class 3")
# axes_dataset_ex1.legend()
axes_dataset_ex1.set_xlabel("x1")
axes_dataset_ex1.set_ylabel("x2")
axes_dataset_ex1.set_xlim([0.0, 1.0])
axes_dataset_ex1.set_ylim([0.0, 1.0])
axes_dataset_ex1.tick_params(axis='both', direction='in', bottom=True, top=True, left=True, right=True)
axes_dataset_ex1.tick_params(axis='both', which='major', length=6)

# データセット描画
axes_dataset_ex2 = fig_dataset.add_subplot(234)
axes_dataset_ex2.set_title("kadai3_pattern2.txt")
axes_dataset_ex2.scatter(dataX1_class1_ex2, dataX2_class1_ex2, marker='o', c="red", label="Class 1")
axes_dataset_ex2.scatter(dataX1_class2_ex2, dataX2_class2_ex2, marker='o', c="blue", label="Class 2")
axes_dataset_ex2.scatter(dataX1_class3_ex2, dataX2_class3_ex2, marker='o', c="green", label="Class 3")
# axes_dataset_ex2.legend()
axes_dataset_ex2.set_xlabel("x1")
axes_dataset_ex2.set_ylabel("x2")
axes_dataset_ex2.set_xlim([0.0, 1.0])
axes_dataset_ex2.set_ylim([0.0, 1.0])
axes_dataset_ex2.tick_params(axis='both', direction='in', bottom=True, top=True, left=True, right=True)
axes_dataset_ex2.tick_params(axis='both', which='major', length=6)

# データセット初期化
dataX1_ex1 = np.asarray([], dtype=np.float64)
dataX2_ex1 = np.asarray([], dtype=np.float64)
dataX1_ex2 = np.asarray([], dtype=np.float64)
dataX2_ex2 = np.asarray([], dtype=np.float64)
# ---------------ファイル読み込み開始---------------
    #Mac(ノートPC)環境用パス
border_path_ex1 = '/Users/Uone/IDrive/OPU/研究フォルダ/Junior_ex3/eclipse_workspace/Junior_ex3/src/border_pattern1.dat'
border_path_ex2 = '/Users/Uone/IDrive/OPU/研究フォルダ/Junior_ex3/eclipse_workspace/Junior_ex3/src/border_pattern2.dat'
    #研究室 Windows環境用パス
# border_path_ex1 = 'C:\\Users\\Yuichi Omozaki\\IDrive\\Junior_ex3\\eclipse_workspace\\Junior_ex3\\src\\border_pattern1.dat'
# border_path_ex2 = 'C:\\Users\\Yuichi Omozaki\\IDrive\\Junior_ex3\\eclipse_workspace\\Junior_ex3\\src\\border_pattern2.dat'

for line in open(border_path_ex1, 'r'):
    dataX1_ex1 = np.append( dataX1_ex1, line[:-2].split('\t')[0] )
    dataX2_ex1 = np.append( dataX2_ex1, line[:-2].split('\t')[1] )

dataX1_ex1 = dataX1_ex1.astype(np.float64) #型変換
dataX2_ex1 = dataX2_ex1.astype(np.float64) #

for line in open(border_path_ex2, 'r'):
    dataX1_ex2 = np.append( dataX1_ex2, line[:-2].split('\t')[0] )
    dataX2_ex2 = np.append( dataX2_ex2, line[:-2].split('\t')[1] )

dataX1_ex2 = dataX1_ex2.astype(np.float64) #型変換
dataX2_ex2 = dataX2_ex2.astype(np.float64) #
# ---------------ファイル読み込み完了---------------

# データセット描画
axes_trained_ex1 = fig_dataset.add_subplot(232)
axes_trained_ex1.set_title("border_pattern1.dat")
axes_trained_ex1.scatter(dataX1_class1_ex1, dataX2_class1_ex1, marker='o', c="red", label="Class 1")
axes_trained_ex1.scatter(dataX1_class2_ex1, dataX2_class2_ex1, marker='o', c="blue", label="Class 2")
axes_trained_ex1.scatter(dataX1_class3_ex1, dataX2_class3_ex1, marker='o', c="green", label="Class 3")
axes_trained_ex1.scatter(dataX1_ex1, dataX2_ex1, s=5, c="red", label="border_of_Class")
# axes_trained_ex1.legend()
axes_trained_ex1.set_xlabel("x1")
axes_trained_ex1.set_ylabel("x2")
axes_trained_ex1.set_xlim([0.0, 1.0])
axes_trained_ex1.set_ylim([0.0, 1.0])
axes_trained_ex1.tick_params(axis='both', direction='in', bottom=True, top=True, left=True, right=True)
axes_trained_ex1.tick_params(axis='both', which='major', length=6)

# データセット描画
axes_trained_ex2 = fig_dataset.add_subplot(235)
axes_trained_ex2.set_title("border_pattern2.dat")
axes_trained_ex2.scatter(dataX1_class1_ex2, dataX2_class1_ex2, marker='o', c="red", label="Class 1")
axes_trained_ex2.scatter(dataX1_class2_ex2, dataX2_class2_ex2, marker='o', c="blue", label="Class 2")
axes_trained_ex2.scatter(dataX1_class3_ex2, dataX2_class3_ex2, marker='o', c="green", label="Class 3")
axes_trained_ex2.scatter(dataX1_ex2, dataX2_ex2, s=5, c="red", label="border_of_Class")
# axes_trained_ex2.legend()
axes_trained_ex2.set_xlabel("x1")
axes_trained_ex2.set_ylabel("x2")
axes_trained_ex2.set_xlim([0.0, 1.0])
axes_trained_ex2.set_ylim([0.0, 1.0])
axes_trained_ex2.tick_params(axis='both', direction='in', bottom=True, top=True, left=True, right=True)
axes_trained_ex2.tick_params(axis='both', which='major', length=6)

# 最適化境界描画
# データセット初期化
dataX1_ex1 = np.asarray([], dtype=np.float64)
dataX2_ex1 = np.asarray([], dtype=np.float64)
dataX1_ex2 = np.asarray([], dtype=np.float64)
dataX2_ex2 = np.asarray([], dtype=np.float64)
# ---------------ファイル読み込み開始---------------
    #Mac(ノートPC)環境用パス
optimum_path_ex1 = '/Users/Uone/IDrive/OPU/研究フォルダ/Junior_ex3/eclipse_workspace/Junior_ex3/src/optimum_pattern1.dat'
optimum_path_ex2 = '/Users/Uone/IDrive/OPU/研究フォルダ/Junior_ex3/eclipse_workspace/Junior_ex3/src/optimum_pattern2.dat'

for line in open(optimum_path_ex1, 'r'):
    dataX1_ex1 = np.append( dataX1_ex1, line[:-2].split('\t')[0] )
    dataX2_ex1 = np.append( dataX2_ex1, line[:-2].split('\t')[1] )

dataX1_ex1 = dataX1_ex1.astype(np.float64) #型変換
dataX2_ex1 = dataX2_ex1.astype(np.float64) #

for line in open(optimum_path_ex2, 'r'):
    dataX1_ex2 = np.append( dataX1_ex2, line[:-2].split('\t')[0] )
    dataX2_ex2 = np.append( dataX2_ex2, line[:-2].split('\t')[1] )

dataX1_ex2 = dataX1_ex2.astype(np.float64) #型変換
dataX2_ex2 = dataX2_ex2.astype(np.float64) #
# ---------------ファイル読み込み完了---------------

# データセット描画
axes_optimum_ex1 = fig_dataset.add_subplot(233)
axes_optimum_ex1.set_title("optimum_pattern1.dat")
axes_optimum_ex1.scatter(dataX1_class1_ex1, dataX2_class1_ex1, marker='o', c="red", label="Class 1")
axes_optimum_ex1.scatter(dataX1_class2_ex1, dataX2_class2_ex1, marker='o', c="blue", label="Class 2")
axes_optimum_ex1.scatter(dataX1_class3_ex1, dataX2_class3_ex1, marker='o', c="green", label="Class 3")
axes_optimum_ex1.scatter(dataX1_ex1, dataX2_ex1, s=5, c="red", label="border_of_Class")
# axes_trained_ex1.legend()
axes_optimum_ex1.set_xlabel("x1")
axes_optimum_ex1.set_ylabel("x2")
axes_optimum_ex1.set_xlim([0.0, 1.0])
axes_optimum_ex1.set_ylim([0.0, 1.0])
axes_optimum_ex1.tick_params(axis='both', direction='in', bottom=True, top=True, left=True, right=True)
axes_optimum_ex1.tick_params(axis='both', which='major', length=6)

axes_optimum_ex2 = fig_dataset.add_subplot(236)
axes_optimum_ex2.set_title("optimum_pattern2.dat")
axes_optimum_ex2.scatter(dataX1_class1_ex2, dataX2_class1_ex2, marker='o', c="red", label="Class 1")
axes_optimum_ex2.scatter(dataX1_class2_ex2, dataX2_class2_ex2, marker='o', c="blue", label="Class 2")
axes_optimum_ex2.scatter(dataX1_class3_ex2, dataX2_class3_ex2, marker='o', c="green", label="Class 3")
axes_optimum_ex2.scatter(dataX1_ex2, dataX2_ex2, s=5, c="red", label="border_of_Class")
# axes_trained_ex1.legend()
axes_optimum_ex2.set_xlabel("x1")
axes_optimum_ex2.set_ylabel("x2")
axes_optimum_ex2.set_xlim([0.0, 1.0])
axes_optimum_ex2.set_ylim([0.0, 1.0])
axes_optimum_ex2.tick_params(axis='both', direction='in', bottom=True, top=True, left=True, right=True)
axes_optimum_ex2.tick_params(axis='both', which='major', length=6)

# fig_dataset.show()
